# %%
import numpy as np

# %%
full_template = np.array(
        [
            [5000, 0, 5000, 0],
            [0, 25000, 0, 25000],
            [5000, 0, 5000, 0],
            [0, 25000, 0, 25000],
            [5000, 0, 5000, 0]
        ],
        dtype = np.uint16
    )
input_array = np.empty(shape=(5, 10, 4), dtype=np.uint16)

# %%
input_array[:,1,:] = full_template

# %%
input_array[:,1,:]
# Out:
# array([[ 5000,     0,  5000,     0],
#        [    0, 25000,     0, 25000],
#        [ 5000,     0,  5000,     0],
#        [    0, 25000,     0, 25000],
#        [ 5000,     0,  5000,     0]], dtype=uint16)

# %%
band_arrangements = [
        "a"
    ]*6 + [
        "b"
    ]*6

# %%
band_arrangements
# Out:
# ['a', 'a', 'a', 'a', 'a', 'a', 'b', 'b', 'b', 'b', 'b', 'b']
